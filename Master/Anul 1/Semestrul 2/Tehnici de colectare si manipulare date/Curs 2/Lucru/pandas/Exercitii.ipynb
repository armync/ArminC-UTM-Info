# %% [markdown]
# # Structuri de date in pandas

# %% [markdown]
# + ## Series
# + ##  Frames

# %% [markdown]
# ---

# %% [markdown]
# ## Series

# %% [markdown]
# Un obiect de tip Series = Obiect de tip 1D array conținând o secvență de valori și o serie de indecsi.
#
# Implicit indecsii sunt 0,1,…, size-1.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
a = pd.Series([1, 2, 3, 4])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.values
# Out:
# array([1, 2, 3, 4])

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
a.size
# Out:
# 4

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a[0]
# Out:
# 1

# %%
a[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# Putem defini si alti indecsi.

# %%
b = pd.Series([2, 3, 7, 1, 0], index=['a', 'b', 'c', 'd', 'e'])
c = pd.Series([2, 4, 5], index = list('xyz'))

# %%
print(b)
print(c)
# Out:
# a    2
# b    3
# c    7
# d    1
# e    0
# dtype: int64
# x    2
# y    4
# z    5
# dtype: int64

# %%
print(b)

print("\n")
print(c[-1])

print("\n")
print(b['a':'c'])

print("\n")
print(b[0:2])
# Out:
# a    2
# b    3
# c    7
# d    1
# e    0
# dtype: int64
#
#
# 5
#
#
# a    2
# b    3
# c    7
# dtype: int64
#
#
# a    2
# b    3
# dtype: int64

# %%
b.values
# Out:
# array([2, 3, 7, 1, 0])

# %%
b.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# Putem folosi indecsi pentru a accesa anumite elemente ale seriei.

# %%
a[1] = 10
a
# Out:
# 0     1
# 1    10
# 2     3
# 3     4
# dtype: int64

# %%
b['c']
# Out:
# 7

# %% [markdown]
# Putem accesa doar o parte din elementele vectorului.

# %%
a[0:2] # accesam elementele cu indicii 0,1
# Out:
# 0     1
# 1    10
# dtype: int64

# %%
x = b['a':'d'] # observati diferenta. in pandas includem si elementul cu ultimul index - adica d

print(x)

type(x)
# Out:
# a    2
# b    3
# c    7
# d    1
# dtype: int64
# pandas.core.series.Series

# %%
print(a[[0,2]])
b[['a', 'c']]
# Out:
# 0    1
# 2    3
# dtype: int64
# a    2
# c    7
# dtype: int64

# %%
print(a[[0,3]]) # aici am precizat lista de indecsi

a[[2, 3]] = 5
print(a)
# Out:
# 0    1
# 3    4
# dtype: int64
# 0     1
# 1    10
# 2     5
# 3     5
# dtype: int64

# %%
b[['d', 'c', 'e']] # aici am precizat lista de indecsi
# Out:
# d    1
# c    7
# e    0
# dtype: int64

# %%
b
# Out:
# a    2
# b    3
# c    7
# d    1
# e    0
# dtype: int64

# %% [markdown]
# Putem modifica valorile unei serii prin intermediul indecsilor.

# %%
b['c']=9

# %%
b
# Out:
# a    2
# b    3
# c    9
# d    1
# e    0
# dtype: int64

# %%
b['b':'d'] = 100
b
# Out:
# a      2
# b    100
# c    100
# d    100
# e      0
# dtype: int64

# %% [markdown]
# Putem aplica operatorii >, <, == unei serii asa cum putem face si in NumPy. Astfel putem accesa doar o parte din elementele seriei.

# %%
a > 2
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# dtype: bool

# %%
a[a > 2]
# Out:
# 1    10
# 2     5
# 3     5
# dtype: int64

# %%
c = a[ a > 2]
c
# Out:
# 1    10
# 2     5
# 3     5
# dtype: int64

# %%
c = pd.Series([2, 4, 5], index = list('xyz'))
print(c)
c.index
# Out:
# x    2
# y    4
# z    5
# dtype: int64
# Index(['x', 'y', 'z'], dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## Ex. 1.

# %% [markdown]
# + Creati o serie s1 cu elementele 10, 15, 20, 25 si index default

# %%
s1 = pd.Series([10,15,20,25])
s1
# Out:
# 0    10
# 1    15
# 2    20
# 3    25
# dtype: int64

# %% [markdown]
# + Creati o serie s2 cu elementele 'luni', 'marti','miercuri', 'joi', 'vineri' si indici 'L', 'Ma', 'Mi', 'J', 'V'

# %%
s2 = pd.Series(['luni','marti','miercuri','joi','vineri'], index=['L','Ma','Mi','J','v'])
s2
# Out:
# L         luni
# Ma       marti
# Mi    miercuri
# J          joi
# v       vineri
# dtype: object

# %% [markdown]
# + Aplicati index si values

# %%
s2.index
# Out:
# Index(['L', 'Ma', 'Mi', 'J', 'v'], dtype='object')

# %%
s2.values
# Out:
# array(['luni', 'marti', 'miercuri', 'joi', 'vineri'], dtype=object)

# %% [markdown]
# Scrieti elementul cu valoarea 'marti'

# %%
s2[s2=='marti']
# Out:
# Ma    marti
# dtype: object

# %% [markdown]
# ---

# %%
import numpy as np
print (np.__version__)
# Out:
# 1.23.5

# %%
a
# Out:
# 0     1
# 1    10
# 2     5
# 3     5
# dtype: int64

# %%
d = np.where(a > 2, a, -1)
d
# Out:
# array([-1, 10,  5,  5])

# %% [markdown]
# Putem forma o serie plecand de la un dictionar Python (dict)

# %%
inaltime = {'Ionel': 176, 'Mihai': 185, 'Maria': 170, 'Anda':160}
inaltime
# Out:
# {'Ionel': 176, 'Mihai': 185, 'Maria': 170, 'Anda': 160}

# %%
tabel_inaltime =  pd.Series(inaltime)

# %%
tabel_inaltime
# Out:
# Ionel    176
# Mihai    185
# Maria    170
# Anda     160
# dtype: int64

# %%
tabel_inaltime.index
# Out:
# Index(['Ionel', 'Mihai', 'Maria', 'Anda'], dtype='object')

# %%
tabel_inaltime.values
# Out:
# array([176, 185, 170, 160])

# %%
tabel_inaltime[['Ionel','Anda']]
# Out:
# Ionel    176
# Anda     160
# dtype: int64

# %% [markdown]
# Putem forma o serie plecand de la o parte din dictionar

# %%
tabel_inaltime2 = pd.Series(inaltime, index =['Maria', 'Ionel'])

# %%
tabel_inaltime2
# Out:
# Maria    170
# Ionel    176
# dtype: int64

# %%
tabel_inaltime3 = pd.Series(inaltime, index =['Maria', 'Ionel', 'Dorin', 'Vasile'])
tabel_inaltime3
# Out:
# Maria     170.0
# Ionel     176.0
# Dorin       NaN
# Vasile      NaN
# dtype: float64

# %% [markdown]
# Pentru etichetele (cheile) 'Dorin' si 'Vasile' nu au fost gasite valori,
# tabelul a fost completat cu NaN (not a number) care marcheaza **datele lipsa**.

# %% [markdown]
# Putem verifica daca o serie contine date lipsa apeland functiile pandas: **isnull** si **notnull** care vor returna valori booleene (True sau False).

# %%
pd.isnull(tabel_inaltime)
tabel_inaltime
# Out:
# Ionel    176
# Mihai    185
# Maria    170
# Anda     160
# dtype: int64

# %%
pd.isnull(tabel_inaltime2)
#tabel_inaltime2
# Out:
# Maria    False
# Ionel    False
# dtype: bool

# %%
pd.isnull(tabel_inaltime3)
# Out:
# Maria     False
# Ionel     False
# Dorin      True
# Vasile     True
# dtype: bool

# %%
pd.notnull(tabel_inaltime3)
# Out:
# Maria      True
# Ionel      True
# Dorin     False
# Vasile    False
# dtype: bool

# %%
pd.notnull(tabel_inaltime2)
# Out:
# Maria    True
# Ionel    True
# dtype: bool

# %% [markdown]
# sau folosim functia metoda **isnull** a obiectului de tip Series

# %%
tabel_inaltime3.isnull()
# Out:
# Maria     False
# Ionel     False
# Dorin      True
# Vasile     True
# dtype: bool

# %%
tabel_inaltime + tabel_inaltime2
#tabel_inaltime2
# Out:
# Anda       NaN
# Ionel    352.0
# Maria    340.0
# Mihai      NaN
# dtype: float64

# %%
# tabel_inaltime + tabel_inaltime2 + tabel_inaltime3 #desi seriile nu au aceeasi dimensiune, nu obtinem eroare
(tabel_inaltime + tabel_inaltime2) + tabel_inaltime3
# Out:
# Anda        NaN
# Dorin       NaN
# Ionel     528.0
# Maria     510.0
# Mihai       NaN
# Vasile      NaN
# dtype: float64

# %%
tabel_inaltime
# Out:
# Ionel    176
# Mihai    185
# Maria    170
# Anda     160
# dtype: int64

# %%
tabel_inaltime2
# Out:
# Maria    170
# Ionel    176
# dtype: int64

# %%
tabel_inaltime3
# Out:
# Maria     170.0
# Ionel     176.0
# Dorin       NaN
# Vasile      NaN
# dtype: float64

# %% [markdown]
# Observati cum a fost facuta adunarea celor 3 serii. Ordonarea se face alfabetic dupa cheile corespunzatoare valorilor adunate.

# %%
tabel_inaltime.name = 'Inaltime' 
tabel_inaltime
# Out:
# Ionel    176
# Mihai    185
# Maria    170
# Anda     160
# Name: Inaltime, dtype: int64

# %%
tabel_inaltime.index.name = 'Nume'

# %%
tabel_inaltime
# Out:
# Nume
# Ionel    176
# Mihai    185
# Maria    170
# Anda     160
# Name: Inaltime, dtype: int64

# %% [markdown]
# # DataFrame

# %% [markdown]
# Un dataframe reprezintă un tabel de date cu linii si coloane, fiecare dintre acestea putând fi de tipuri diferite (numeric, șir, boolean etc.)

# %% [markdown]
# DataFrame are un index pentru rânduri și pentru coloane; poate fi gândit ca un dict de Series, toate avand același index.

# %% [markdown]
# Putem construi un Dataframe plecand de la un dictionar de liste

# %%
data = {'Vant': ['T', 'F','T', 'T'], 'Temperatura': [15, 20, 7, 10], 'Umiditate': ['scazuta', 'normala', 'ridicata', 'normala']}

# %%
data
# Out:
# {'Vant': ['T', 'F', 'T', 'T'],
#  'Temperatura': [15, 20, 7, 10],
#  'Umiditate': ['scazuta', 'normala', 'ridicata', 'normala']}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Vant  Temperatura Umiditate
# 0    T           15   scazuta
# 1    F           20   normala
# 2    T            7  ridicata
# 3    T           10   normala

# %% [markdown]
# Putem preciza ordinea coloanelor. Putem adauga coloane noi. Cele fara valori apar cu NaN.

# %%
df2 = pd.DataFrame(data, columns =['Temperatura', 'Vant', 'Umiditate', 'Clasa'])
df3 = pd.DataFrame(data, columns =['Temperatura', 'Vant', 'Umiditate'])
df2
# Out:
#    Temperatura Vant Umiditate Clasa
# 0           15    T   scazuta   NaN
# 1           20    F   normala   NaN
# 2            7    T  ridicata   NaN
# 3           10    T   normala   NaN

# %%
print(df2['Vant'])
type(df2['Vant'])
# Out:
# 0    T
# 1    F
# 2    T
# 3    T
# Name: Vant, dtype: object
# pandas.core.series.Series

# %%
df2['Vant'][1]
# Out:
# 'F'

# %%
df2.dtypes
# Out:
# Temperatura     int64
# Vant           object
# Umiditate      object
# Clasa          object
# dtype: object

# %% [markdown]
# Putem construi un Dataframe plecand de la un dictionar ce contine si o serie.

# %%
d = {'Temperatura': [3, 10, 17, 10], 'Temp_noaptea': pd.Series([3, 8, 12], index = [0,2,3])}
#d = {'Temp_noaptea': pd.Series([3, 8, 12], index = [0,2,3])}
d
#df_1_2 = pd.DataFrame(d, index=range(4))
#df_1_2
# Out:
# {'Temperatura': [3, 10, 17, 10],
#  'Temp_noaptea': 0     3
#  2     8
#  3    12
#  dtype: int64}

# %%
df_3 = pd.DataFrame(d, index=range(4))
df_3
# Out:
#    Temperatura  Temp_noaptea
# 0            3           3.0
# 1           10           NaN
# 2           17           8.0
# 3           10          12.0

# %%
v = pd.Series([3, 8, 12], index = [0,2,3])

# %%
v
# Out:
# 0     3
# 2     8
# 3    12
# dtype: int64

# %%
d2 =  {'Temp_noaptea': v}

# %%
d2
# Out:
# {'Temp_noaptea': 0     3
#  2     8
#  3    12
#  dtype: int64}

# %%
df_4 = pd.DataFrame(d2, index = [0,1,2,3])

# %%
df_4
# Out:
#    Temp_noaptea
# 0           3.0
# 1           NaN
# 2           8.0
# 3          12.0

# %% [markdown]
# ---

# %% [markdown]
# ## Ex. 2.

# %% [markdown]
# + Plecand de la un dictionar, creati un DataFrame care sa corespunda urmatorului tabel:
#
# |   | Cantitate | Pret unitar | Cantitate maxima | Vandut | Pret total |
# |---|-----------|-------------|------------------|--------|------------|
# | 1 | 23        | 14.99       | 100              | False  | NaN        |
# | 2 | 45        | 23.50       | 100              | False  | NaN        |
# | 3 | 15        | 58.00       | 100              | False  | NaN        |
# | 4 | 34        | 76.25       | 100              | False  | NaN        |

# %%
d = {'Cantitate': [23, 45, 15, 34], 'Pret unitar': [14.99, 23.50, 58.00, 76.25], 'Cantitate maxima': np.full(4,100), 'Vandut': np.full(4, False), 'Pret total': [np.nan, np.nan, np.nan, np.nan]}
print(d)

df2 = pd.DataFrame(d,index=range(4))
df2
# Out:
# {'Cantitate': [23, 45, 15, 34], 'Pret unitar': [14.99, 23.5, 58.0, 76.25], 'Cantitate maxima': array([100, 100, 100, 100]), 'Vandut': array([False, False, False, False]), 'Pret total': [nan, nan, nan, nan]}
#    Cantitate  Pret unitar  Cantitate maxima  Vandut  Pret total
# 0         23        14.99               100   False         NaN
# 1         45        23.50               100   False         NaN
# 2         15        58.00               100   False         NaN
# 3         34        76.25               100   False         NaN

# %% [markdown]
# Putem construi un Dataframe plecand de la un sir de vectori Numpy

# %%
import numpy as np

# %%
t =  pd.DataFrame(np.array([[1,4,8,5], [5,3,2,1], [6,7,8,9]]), columns = list('xyzt'))

# %%
t
# Out:
#    x  y  z  t
# 0  1  4  8  5
# 1  5  3  2  1
# 2  6  7  8  9

# %%
t2 =  pd.DataFrame(np.array([[1, 2, 0, 5], [5,-3,2,1], [6,7,-8,9]]), columns = list('xyzt'),index = ['unu', 'doi', 'trei'])

# %%
t2
# Out:
#       x  y  z  t
# unu   1  2  0  5
# doi   5 -3  2  1
# trei  6  7 -8  9

# %% [markdown]
# Selectare coloane

# %%
t2['x']  # coloana cu numele x
# sau 
t2.x  # daca numele coloanei are formatul de nume de variabila Python
# Out:
# unu     1
# doi     5
# trei    6
# Name: x, dtype: int64

# %%
t2['x']= 6
t2
# Out:
#       x  y  z  t
# unu   6  2  0  5
# doi   6 -3  2  1
# trei  6  7 -8  9

# %%
t2[ t2 > 0 ]
# Out:
#       x    y    z  t
# unu   6  2.0  NaN  5
# doi   6  NaN  2.0  1
# trei  6  7.0  NaN  9

# %%
print(t2[t2['y'] > 1])
print(type(t2['x']))
print(t2)
# Out:
#       x  y  z  t
# unu   6  2  0  5
# trei  6  7 -8  9
# <class 'pandas.core.series.Series'>
#       x  y  z  t
# unu   6  2  0  5
# doi   6 -3  2  1
# trei  6  7 -8  9

# %%
t2['t'] = t2['x'] + t2['y']  # putem modifica o coloana 
t2
# Out:
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %% [markdown]
# ---

# %% [markdown]
# ## Ex. 3.

# %% [markdown]
# + In DataFrame-ul creat la ex. 2,
#
# |   | Cantitate | Pret unitar | Pret total |
# |---|-----------|-------------|------------|
# | 1 | 23        | 14.99       | NaN        |
# | 2 | 45        | 23.65       | NaN        |
# | 3 | 15        | 59.00       | NaN        |
# | 4 | 34        | 76.00       | NaN        |
#
# modificati coloana **_Pret total_** astfel incat sa reprezinte pretul total al produselor achizitionate (**_Cantitate_** = nr de produse, **_Pret unitar_** = pretul fiecarui produs).

# %%
df2['Pret total'] = df2['Cantitate'] * df2['Pret unitar']
df2
# Out:
#    Cantitate  Pret unitar  Cantitate maxima  Vandut  Pret total
# 0         23        14.99               100   False      344.77
# 1         45        23.50               100   False     1057.50
# 2         15        58.00               100   False      870.00
# 3         34        76.25               100   False     2592.50

# %% [markdown]
# ---

# %% [markdown]
# Selectare linii

# %%
print(t2.loc['unu']) # linia cu index 'unu' | label based
t2
# Out:
# x    6
# y    2
# z    0
# t    8
# Name: unu, dtype: int64
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
t2
# Out:
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
t2.loc[['unu','doi']]
# Out:
#      x  y  z  t
# unu  6  2  0  8
# doi  6 -3  2  3

# %%
t2.loc['unu':'trei'] # observati ca este inclusa si linia cu indexul 'trei'
# label-based slicing in pandas is inclusive.
# Out:
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
t2.loc[['unu','doi'],'y']
# Out:
# unu    2
# doi   -3
# Name: y, dtype: int64

# %%
t2
# Out:
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
t2.iloc[2] # linia cu indexul numeric 2 (de la 0 incepand numerotarea) | numerical indices based
# Out:
# x     6
# y     7
# z    -8
# t    13
# Name: trei, dtype: int64

# %%
t2.iloc[2,2] # elem de pe linia 2 col 2 (de la 0 incepand numerotarea)
# Out:
# -8

# %%
print(t2.iloc[0:3:2]) # from, to, step
t2
# Out:
#       x  y  z   t
# unu   6  2  0   8
# trei  6  7 -8  13
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
print(t2.iloc[:,0:5:2]) # x,y - row , column (0:5:2 step)
t2.dtypes
# Out:
#       x  z
# unu   6  0
# doi   6  2
# trei  6 -8
# x    int64
# y    int64
# z    int64
# t    int64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Ex.4.

# %% [markdown]
# + Creati un DataFrame care sa corespunda urmatorului tabel: (pt valoarea NaN (not-a-number) puteti folosi *np.nan* sau *None*)
#
# |         | Nota romana | Nota matematica |
# |---------|-------------|-----------------|
# | a       | 10.0        | 8.0             |
# | b       | 8.0         | 10.0            |
# | c       | NaN         | 7.0             |
# | d       | 8.0         | 6.0             |
# | e       | 9.0         | NaN             |

# %%
df_ex4_test = pd.DataFrame(np.array([[10.0,8.0,np.nan,8.0,9.0],[8.0,10.0,7.0,6.0,np.nan]]).T,columns=['Nota romana','Nota matematica'],index=['a','b','c','d','e']) # transpose (2,5) -> (5,2)

df_ex4 = pd.DataFrame({"Nota romana": [10.0, 8.0, np.nan, 8.0, 9.0], "Nota matematica": [8.0, 10.0, 7.0, 6.0, np.nan]}, index=['a', 'b', 'c', 'd', 'e'])

print(df_ex4)
# Out:
#    Nota romana  Nota matematica
# a         10.0              8.0
# b          8.0             10.0
# c          NaN              7.0
# d          8.0              6.0
# e          9.0              NaN

# %% [markdown]
# + Afisati toate notele la romana.

# %%
df_ex4.iloc[0:5,0]
# Out:
# a    10.0
# b     8.0
# c     NaN
# d     8.0
# e     9.0
# Name: Nota romana, dtype: float64

# %% [markdown]
# + Afisati elementele de pe linia 'b'

# %%
df_ex4.loc['b','Nota romana':'Nota matematica']
# Out:
# Nota romana         8.0
# Nota matematica    10.0
# Name: b, dtype: float64

# %% [markdown]
# + Scrieti mai multe instructiunile care vor genera toate notele de 8
#
#     - accesand coloanele
#     - accesand liniile (loc si cu iloc)
#     - cu **df[df==8]**

# %%
print(df_ex4)

print('\n')

print(df_ex4[df_ex4 == 8])

print('\n')

print(df_ex4.iloc[[1, 3], [0, 1]])

print('\n')

print(df_ex4.loc[['b', 'd'], ['Nota romana', 'Nota matematica']])
# Out:
#    Nota romana  Nota matematica
# a         10.0              8.0
# b          8.0             10.0
# c          NaN              7.0
# d          8.0              6.0
# e          9.0              NaN
#
#
#    Nota romana  Nota matematica
# a          NaN              8.0
# b          8.0              NaN
# c          NaN              NaN
# d          8.0              NaN
# e          NaN              NaN
#
#
#    Nota romana  Nota matematica
# b          8.0             10.0
# d          8.0              6.0
#
#
#    Nota romana  Nota matematica
# b          8.0             10.0
# d          8.0              6.0

# %% [markdown]
# ---

# %% [markdown]
# Putem adauga o coloana noua.

# %%
t2
# Out:
#       x  y  z   t
# unu   6  2  0   8
# doi   6 -3  2   3
# trei  6  7 -8  13

# %%
t2['p'] = pd.Series([2, 4, 5], index = ['unu', 'doi', 'trei'])
t2
# Out:
#       x  y  z   t  p
# unu   6  2  0   8  2
# doi   6 -3  2   3  4
# trei  6  7 -8  13  5

# %% [markdown]
# Putem sterge o coloana.

# %%
del t2['x']
t2
# Out:
#       y  z   t  p
# unu   2  0   8  2
# doi  -3  2   3  4
# trei  7 -8  13  5

# %%
t2.values
# Out:
# array([[ 2,  0,  8,  2],
#        [-3,  2,  3,  4],
#        [ 7, -8, 13,  5]])

# %%
t2.index
# Out:
# Index(['unu', 'doi', 'trei'], dtype='object')

# %%
t2
# Out:
#       y  z   t  p
# unu   2  0   8  2
# doi  -3  2   3  4
# trei  7 -8  13  5

# %% [markdown]
# Putem sterge o coloana cu functia drop (va crea o noua DataFrame fara coloana respectiva). Nu modifica dataFrame-ul cum o face functia del.

# %%
t2.drop(columns={'t'})
# Out:
#       y  z  p
# unu   2  0  2
# doi  -3  2  4
# trei  7 -8  5

# %%
t2
# Out:
#       y  z   t  p
# unu   2  0   8  2
# doi  -3  2   3  4
# trei  7 -8  13  5

# %%
print(t2.drop(columns=['y','t']))
t2
# Out:
#       y  z   t  p
# unu   2  0   8  2
# doi  -3  2   3  4
# trei  7 -8  13  5

# %%
t2 = t2.drop(columns={'t'}) # daca vrem ca sa t2 sa se schimbe in urma aplicarii functiei drop
t2
# Out:
#       y  z  p
# unu   2  0  2
# doi  -3  2  4
# trei  7 -8  5

# %% [markdown]
# Putem sterge si linii. Folosim parametrul axis = 1

# %%
df_4
# Out:
#    Temp_noaptea
# 0           3.0
# 1           NaN
# 2           8.0
# 3          12.0

# %%
df_4 = df_4.drop(axis =1, index = range(2,4)) # axis 0 - columns, axis 1 - rows

# %%
df_4
# Out:
#    Temp_noaptea
# 0           3.0
# 1           NaN

# %% [markdown]
# ---

# %% [markdown]
# ## Ex.5.

# %% [markdown]
# + In dataFrame-ul creat la ex. 4, inserati coloana 'Nota fizica' cu valorile [6, 8, 7, 10, 9]

# %%
df_ex4['Nota fizica'] = [6,8,7,10,9]

df_ex4
# Out:
#    Nota romana  Nota matematica  Nota fizica
# a         10.0              8.0            6
# b          8.0             10.0            8
# c          NaN              7.0            7
# d          8.0              6.0           10
# e          9.0              NaN            9

# %% [markdown]
# + Creati o copie a tabelulul fara coloana 'Nota romana'.

# %%
df_ex4_copie = df_ex4.drop(columns=['Nota romana'])
df_ex4_copie
# Out:
#    Nota matematica  Nota fizica
# a              8.0            6
# b             10.0            8
# c              7.0            7
# d              6.0           10
# e              NaN            9

# %% [markdown]
# + Scrieti instructiunile pentru a sterge complet coloana 'Nota romana'.

# %%
df_ex4 = df_ex4.drop(columns=['Nota romana']) 
df_ex4
# Out:
#    Nota matematica  Nota fizica
# a              8.0            6
# b             10.0            8
# c              7.0            7
# d              6.0           10
# e              NaN            9

# %% [markdown]
# + Creati o copie a DF fara liniile a si e

# %%
df_ex4_copie = df_ex4.drop(axis=1,index=['a','e'])
df_ex4_copie
# Out:
#    Nota matematica  Nota fizica
# b             10.0            8
# c              7.0            7
# d              6.0           10
