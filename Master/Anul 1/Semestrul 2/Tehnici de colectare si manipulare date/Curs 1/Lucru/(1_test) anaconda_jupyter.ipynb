# %% [markdown]
# # Curs introductiv
# ## 1.1 Variabile

# %%
a=2
b = 7

# %%
a
# Out:
# 2

# %%
a = 5
a
# Out:
# 5

# %%
a = 3 
b = 8
a
b
# Out:
# 8

# %% [markdown]
# Lista in python

# %%
v = [1, 2, 3, 4]
v
# Out:
# [1, 2, 3, 4]
